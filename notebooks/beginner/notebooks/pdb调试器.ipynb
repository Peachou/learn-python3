# %% [markdown]
# # [`pdb`](https://docs.python.org/3/library/pdb.html#module-pdb) --Python调试器
# 您的程序如果出现非预期的行为。，如果错误的根源尚不清楚，则调试通常是查找意外行为根本原因的最有效方法。 Python标准库具有内置调试器，该调试器是解决与代码相关的任何问题的强大工具。

# %% [markdown]
# ## `import pdb; pdb.set_trace()`
# 调试的基本用例是，您希望在某个特定点停止程序的执行，并从该特定点开始监视变量值或一般情况下的程序执行。 通过导入pdb在代码中设置断点，可以在所需的点停止执行。 pdb.set_trace（）（在Python版本> = 3.7中请注意，有一个快捷方式：breakpoint（））。
#
# 当您执行程序时，执行将在此时停止并进入交互式调试器会话。 您可以根据需要在代码中添加任意多个断点。

# %% [markdown]
# ## 有用的命令
# 全部指令列表 [点击这里](https://docs.python.org/3/library/pdb.html#debugger-commands).
#
# * `h` or `help`: 打印可用命令列表。 如果您提出意见，例如 `help continue`，输出`continue`命令的帮助。
# * `l` or `list`: 列出当前位置周围的一段代码。
# * `n` or `next`: 执行下一行。
# * `s` or `step`: 与`next`相同，但是“进入”下一行中调用的函数。
# * `c` or `continue`: 继续执行直到下一个断点。
# * `r` or `return`: 继续执行直到返回当前函数。
# * `q` or `quit`: 退出调试器并中止程序执行。
#
# 请注意，通过在调试会话期间键入变量名称，可以看到任何变量的值。 你还可以在调试会话期间执行任意代码。

# %% [markdown]
# ## 让我们看看它是如何工作的
# 取消注释`import pdb;。 pdb.set_trace（）`行并执行单元。 使用上面定义的命令逐行执行程序。 至少尝试上述所有命令一次。 注意`n`和`s`之间的区别。

# %%
class SuperGreeter:
    def __init__(self, people_to_greet):
        self.people = people_to_greet

    def greet(self):
        for person in self.people:
            if person.islower():
                self._greet_street_style(person)
            elif len(person) > 7:
                self._greet_hawaii(person)
            else:
                self._greet_polite(person)
            
    def _greet_polite(self, name):
        greeting = "G'day {}! How are you doing?".format(name)
        print(greeting)

    def _greet_street_style(self, name):
        # import pdb; pdb.set_trace()  # UNCOMMENT
        name = name.upper()
        print('WASSUP {}!?'.format(name))

    def _greet_hawaii(self, name):
        print('Aloha {}!'.format(name))


def main():
    people = ['John Doe', 'Donald', 'Lisa', 'alex']
    # import pdb; pdb.set_trace()  # UNCOMMENT
    greeter = SuperGreeter(people)
    greeter.greet()


main()
# Out:
# > <ipython-input-2-143d58679403>(30)main()
#      28     people = ['John Doe', 'Donald', 'Lisa', 'alex']
#      29     import pdb; pdb.set_trace()  # UNCOMMENT
# ---> 30     greeter = SuperGreeter(people)
#      31     greeter.greet()
#      32
#
# > <ipython-input-2-143d58679403>(31)main()
#      29     import pdb; pdb.set_trace()  # UNCOMMENT
#      30     greeter = SuperGreeter(people)
# ---> 31     greeter.greet()
#      32
#      33
#
# Aloha John Doe!
# G'day Donald! How are you doing?
# G'day Lisa! How are you doing?
# > <ipython-input-2-143d58679403>(20)_greet_street_style()
#      18     def _greet_street_style(self, name):
#      19         import pdb; pdb.set_trace()  # UNCOMMENT
# ---> 20         name = name.upper()
#      21         print('WASSUP {}!?'.format(name))
#      22
#
# > <ipython-input-2-143d58679403>(21)_greet_street_style()
#      19         import pdb; pdb.set_trace()  # UNCOMMENT
#      20         name = name.upper()
# ---> 21         print('WASSUP {}!?'.format(name))
#      22
#      23     def _greet_hawaii(self, name):
#
# WASSUP ALEX!?
# --Return--
# None
# > <ipython-input-2-143d58679403>(21)_greet_street_style()
#      19         import pdb; pdb.set_trace()  # UNCOMMENT
#      20         name = name.upper()
# ---> 21         print('WASSUP {}!?'.format(name))
#      22
#      23     def _greet_hawaii(self, name):
#
# > <ipython-input-2-143d58679403>(6)greet()
#       4
#       5     def greet(self):
# ----> 6         for person in self.people:
#       7             if person.islower():
#       8                 self._greet_street_style(person)
#
# --Return--
# None
# > <ipython-input-2-143d58679403>(6)greet()
#       4
#       5     def greet(self):
# ----> 6         for person in self.people:
#       7             if person.islower():
#       8                 self._greet_street_style(person)
#
# --Return--
# None
# > <ipython-input-2-143d58679403>(31)main()
#      29     import pdb; pdb.set_trace()  # UNCOMMENT
#      30     greeter = SuperGreeter(people)
# ---> 31     greeter.greet()
#      32
#      33
#
# --Call--
# > c:\users\administrator\appdata\local\programs\python\python39\lib\site-packages\ipython\core\displayhook.py(252)__call__()
#     250         sys.stdout.flush()
#     251
# --> 252     def __call__(self, result=None):
#     253         """Printing with history cache management.
#     254
#
# > c:\users\administrator\appdata\local\programs\python\python39\lib\site-packages\ipython\core\displayhook.py(258)__call__()
#     256         activated by setting the variable sys.displayhook to it.
#     257         """
# --> 258         self.check_for_underscore()
#     259         if result is not None and not self.quiet():
#     260             self.start_displayhook()
#
# > c:\users\administrator\appdata\local\programs\python\python39\lib\site-packages\ipython\core\displayhook.py(259)__call__()
#     257         """
#     258         self.check_for_underscore()
# --> 259         if result is not None and not self.quiet():
#     260             self.start_displayhook()
#     261             self.write_output_prompt()
#
# --Return--
# None
# > c:\users\administrator\appdata\local\programs\python\python39\lib\site-packages\ipython\core\displayhook.py(259)__call__()
#     257         """
#     258         self.check_for_underscore()
# --> 259         if result is not None and not self.quiet():
#     260             self.start_displayhook()
#     261             self.write_output_prompt()
#
# --Return--
# None
# > <ipython-input-2-143d58679403>(34)<module>()
#      30     greeter = SuperGreeter(people)
#      31     greeter.greet()
#      32
#      33
# ---> 34 main()
#
#     [... skipped 1 hidden frame]
#
#     [... skipped 1 hidden frame]
#
#     [... skipped 1 hidden frame]
#
#     [... skipped 1 hidden frame]
#
# > c:\users\administrator\appdata\local\programs\python\python39\lib\site-packages\ipython\core\interactiveshell.py(3330)run_ast_nodes()
#    3328                     to_run.append((node, 'single'))
#    3329
# -> 3330                 for node,mode in to_run:
#    3331                     if mode == 'exec':
#    3332                         mod = Module([node], [])
#
# > c:\users\administrator\appdata\local\programs\python\python39\lib\site-packages\ipython\core\interactiveshell.py(3342)run_ast_nodes()
#    3340
#    3341             # Flush softspace
# -> 3342             if softspace(sys.stdout, 0):
#    3343                 print()
#    3344
#
# > c:\users\administrator\appdata\local\programs\python\python39\lib\site-packages\ipython\core\interactiveshell.py(3360)run_ast_nodes()
#    3358             return True
#    3359
# -> 3360         return False
#    3361
#    3362     def _async_exec(self, code_obj: types.CodeType, user_ns: dict):
#
# Internal StopIteration: False
# > c:\users\administrator\appdata\local\programs\python\python39\lib\site-packages\ipython\core\interactiveshell.py(3146)run_cell_async()
#    3144                     interactivity = 'async'
#    3145
# -> 3146                 has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    3147                        interactivity=interactivity, compiler=compiler, result=result)
#    3148
#
# > c:\users\administrator\appdata\local\programs\python\python39\lib\site-packages\ipython\core\interactiveshell.py(3149)run_cell_async()
#    3147                        interactivity=interactivity, compiler=compiler, result=result)
#    3148
# -> 3149                 self.last_execution_succeeded = not has_raised
#    3150                 self.last_execution_result = result
#    3151
#
# > c:\users\administrator\appdata\local\programs\python\python39\lib\site-packages\ipython\core\interactiveshell.py(3150)run_cell_async()
#    3148
#    3149                 self.last_execution_succeeded = not has_raised
# -> 3150                 self.last_execution_result = result
#    3151
#    3152                 # Reset this so later displayed values do not modify the
#
# > c:\users\administrator\appdata\local\programs\python\python39\lib\site-packages\ipython\core\interactiveshell.py(3154)run_cell_async()
#    3152                 # Reset this so later displayed values do not modify the
#    3153                 # ExecutionResult
# -> 3154                 self.displayhook.exec_result = None
#    3155
#    3156         if store_history:
#
# > c:\users\administrator\appdata\local\programs\python\python39\lib\site-packages\ipython\core\interactiveshell.py(3156)run_cell_async()
#    3154                 self.displayhook.exec_result = None
#    3155
# -> 3156         if store_history:
#    3157             # Write output to the database. Does nothing unless
#    3158             # history output logging is enabled.
#
# > c:\users\administrator\appdata\local\programs\python\python39\lib\site-packages\ipython\core\interactiveshell.py(3159)run_cell_async()
#    3157             # Write output to the database. Does nothing unless
#    3158             # history output logging is enabled.
# -> 3159             self.history_manager.store_output(self.execution_count)
#    3160             # Each cell is a *single* input, regardless of how many lines it has
#    3161             self.execution_count += 1
